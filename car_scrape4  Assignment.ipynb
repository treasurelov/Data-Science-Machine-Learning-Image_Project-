# %% [markdown]
# # ASSIGNMENT   2

# %% [markdown]
# # car_scrape4

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # QUEST          1

# %%
# Quest: import the car_price dataset
car_scrape4 = pd.read_csv('C:\\Datasets\\car_scrape4.csv')
car_scrape4.head()
# Out:
#                    title  odometer location    isimported          engine  \
# 0         Toyota Corolla     60127    Lagos  Locally used  4-cylinder(I4)
# 1              Acura MDX    132908    Lagos  Foreign Used  6-cylinder(V6)
# 2           Lexus ES 350    120412    Lagos  Locally used  6-cylinder(V6)
# 3  Mercedes-Benz GLK 350     67640    Lagos  Foreign Used  4-cylinder(I4)
# 4    Mercedes-Benz E 200     92440    Abuja  Foreign Used  4-cylinder(I4)
#
#   transmission    fuel   paint    price  year
# 0    automatic  petrol  Silver  1995000  2009
# 1    automatic  petrol  Whine   3315000  2009
# 2    automatic  petrol  Silver  2355000  2008
# 3    automatic  petrol   Black  9915000  2013
# 4    automatic  petrol   Black  9790000  2013

# %% [markdown]
# # QUEST 2

# %%
# Quest: extract all the values that is not null from the dataset to a new variable
car_scrape4[car_scrape4.notnull()].head()
car_scrape4
# Out:
#                       title  odometer location    isimported          engine  \
# 0            Toyota Corolla     60127    Lagos  Locally used  4-cylinder(I4)
# 1                 Acura MDX    132908    Lagos  Foreign Used  6-cylinder(V6)
# 2              Lexus ES 350    120412    Lagos  Locally used  6-cylinder(V6)
# 3     Mercedes-Benz GLK 350     67640    Lagos  Foreign Used  4-cylinder(I4)
# 4       Mercedes-Benz E 200     92440    Abuja  Foreign Used  4-cylinder(I4)
# ...                     ...       ...      ...           ...             ...
# 3171          Ford Explorer    108597    Abuja  Foreign Used  6-cylinder(V6)
# 3172              Ford Edge    145184    Lagos  Foreign Used  6-cylinder(I6)
# 3173           Toyota Camry     88687    Lagos  Foreign Used  4-cylinder(I4)
# 3174      Toyota Highlander     30951    Lagos  Foreign Used  6-cylinder(V6)
# 3175           Toyota Camry     12936    Lagos  Foreign Used  4-cylinder(I4)
#
# ...

# %% [markdown]
# # QUEST           3

# %%
# Quest: extract all the null value from the dataset into a new variable
car_scrape4[car_scrape4.isnull()].head()
car_scrape4
# Out:
#                       title  odometer location    isimported          engine  \
# 0            Toyota Corolla     60127    Lagos  Locally used  4-cylinder(I4)
# 1                 Acura MDX    132908    Lagos  Foreign Used  6-cylinder(V6)
# 2              Lexus ES 350    120412    Lagos  Locally used  6-cylinder(V6)
# 3     Mercedes-Benz GLK 350     67640    Lagos  Foreign Used  4-cylinder(I4)
# 4       Mercedes-Benz E 200     92440    Abuja  Foreign Used  4-cylinder(I4)
# ...                     ...       ...      ...           ...             ...
# 3171          Ford Explorer    108597    Abuja  Foreign Used  6-cylinder(V6)
# 3172              Ford Edge    145184    Lagos  Foreign Used  6-cylinder(I6)
# 3173           Toyota Camry     88687    Lagos  Foreign Used  4-cylinder(I4)
# 3174      Toyota Highlander     30951    Lagos  Foreign Used  6-cylinder(V6)
# 3175           Toyota Camry     12936    Lagos  Foreign Used  4-cylinder(I4)
#
# ...

# %% [markdown]
# # QUEST    4

# %%
# Quest: drop all columns where all value is null from the original dataset

# %% [markdown]
# # QUEST   5

# %%
# Quest:  clean the dataset so it deosn't have any null value again

# %% [markdown]
# # QUEST    6

# %%
# Quest:  compute the sum, mean of the price column on the dataset
price_column = car_scrape4['price'].values
price_data = pd.Series(price_column) 
price_data
# Out:
# 0        1995000
# 1        3315000
# 2        2355000
# 3        9915000
# 4        9790000
#           ...
# 3171     8675000
# 3172     4437000
# 3173     3175000
# 3174    17535000
# 3175    17015000
# Length: 3176, dtype: int64

# %%
# price.sum()
print("sum:", price_column.sum())
# Out:
# sum: 27214291658

# %%
# price.mean()
print("mean:", np.mean(price_data))
# Out:
# mean: 8568731.630352644

# %% [markdown]
# # QUEST         7

# %%
# Quest:  get the car with the lowest price and with the highest price
# Lowest and the Highest Car Price
print("highest car price:", max(price_column))
print("lowest car price:", min(price_column))
# Out:
# highest car price: 167015008
# lowest car price: 215000
